# %% [markdown]
# <a href="https://colab.research.google.com/github/truth-breaker/DATA-SCIENCE/blob/main/Netflix_cleaning_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
netflix_data = pd.read_csv('netflix_data.csv')

# %%
netflix_data.shape
# Out:
# (7787, 11)

# %%
netflix_data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
#group by director and get the first few rows
netflix_data.groupby('director').count().head()
# Out:
#                  show_id  type  title  cast  country  date_added  \
# director
# A. L. Vijay            2     2      2     2        2           2
# A. Raajdheep           1     1      1     1        1           1
# A. Salaam              1     1      1     1        1           1
# A.R. Murugadoss        2     2      2     2        1           2
# Aadish Keluskar        1     1      1     1        1           1
#
#                  release_year  rating  duration  genres
# director
# A. L. Vijay                 2       2         2       2
# A. Raajdheep                1       1         1       1
# A. Salaam                   1       1         1       1
# A.R. Murugadoss             2       2         2       2
# Aadish Keluskar             1       1         1       1

# %%
#sort values in "release_year"
# To get the release yrs in ascending order
netflix_data.sort_values("release_year", ascending = True)
# Out:
#      show_id     type                                              title  \
# 4298   s4868  TV Show                  Pioneers: First Women Filmmakers*
# 4402   s4961    Movie                                     Prelude to War
# 5688   s6118    Movie                               The Battle of Midway
# 7423   s7680    Movie                    WWII: Report from the Aleutians
# 7353   s7617    Movie                 Why We Fight: The Battle of Russia
# ...      ...      ...                                                ...
# 4125   s4711    Movie                                   Outside the Wire
# 6337   s6702  TV Show                             The Netflix Afterparty
# 4562   s5104    Movie  Ratones Paranoicos: The Band that Rocked Argen...
# 5401   s5860    Movie                                        Stuck Apart
# 589    s1529    Movie                        Creating The Queen's Gambit
#
#                              director  \
# 4298                              NaN
# ...

# %%
netflix_data["release_year"].sort_values()
# Out:
# 4298    1925
# 4402    1942
# 5688    1942
# 7423    1943
# 7353    1943
#         ...
# 4125    2021
# 6337    2021
# 4562    2021
# 5401    2021
# 589     2021
# Name: release_year, Length: 7787, dtype: int64

# %%
#get number of missing values in each column of the data frame
netflix_data.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# dtype: int64

# %%
#Get the total number of rows that contain missing values
netflix_data.isna().sum().sum()
# Out:
# np.int64(3631)

# %%
#Percentage of rows with missing values
(netflix_data.isna().sum().sum()/netflix_data.shape[0])*100
# Out:
# np.float64(46.628997046359316)

# %%
#Drop rows with missing values
netflix_data = netflix_data.dropna()

# %%
#confirm shape after dropping rows
netflix_data.shape
# Out:
# (4808, 11)

# %%
#Investigate for duplicates
netflix_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Get the data type of "date_added" column
netflix_data["date_added"].dtype
# Out:
# dtype('O')

# %%
#Get the data type of first entry in "data_added" column
type(netflix_data["date_added"].iloc[0])
# Out:
# str

# %%
#Convert the "date_added" column after converting to datetime format
netflix_data["date_added"] = pd.to_datetime(netflix_data["date_added"])
# Out:
# /tmp/ipython-input-3151629877.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   netflix_data["date_added"] = pd.to_datetime(netflix_data["date_added"])

# %%
#display "date_added" column after converting to datetime format
netflix_data["date_added"]
# Out:
# 1      2017-12-15
# 2      2019-01-05
# 3      2016-03-01
# 5      2019-02-25
# 6      2021-01-01
#           ...
# 7778   2019-06-21
# 7781   2019-10-01
# 7784   2016-08-26
# 7785   2019-03-08
# 7786   2016-12-06
# Name: date_added, Length: 4808, dtype: datetime64[ns]

# %%
#get the data type of the "release_year"
netflix_data["release_year"].dtype

#type(netflix_data["release_year"].iloc[0])
# Out:
# dtype('int64')
